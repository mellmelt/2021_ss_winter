# %% [markdown]
# <a href="https://colab.research.google.com/github/mellmelt/2021_ss_winter/blob/main/04_%EB%B3%80%EC%88%98(%ED%95%99%EC%83%9D).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 변수
# 컴퓨터 프로그래밍에서 **변수(變數, variable)** 또는 스칼라(scalar)는 아직 알려지지 않거나 어느 정도까지만 알려져 있는 양이나 정보에 대한 상징적인 이름이다. 컴퓨터 소스 코드에서의 **변수 이름**은 일반적으로 데이터 저장 위치와 그 안의 내용물과 관련되어 있으며 이러한 것들은 프로그램 실행 도중에 변경될 수 있다.
#
# 프로그래밍에서의 변수는 수학에서 말하는 변수의 개념과 완전히 일치하지 않을 수도 있다. 컴퓨터 변수의 값은 수학에서처럼 등식이나 공식의 필수적인 부분이 아니다. **컴퓨터 환경에서 변수는 반복적인 과정 안에서 이용할 수도 있다.** 이를테면 한 장소의 값을 할당한 뒤 어느 곳에서 사용한 다음 새로운 값으로 다시 할당하고 같은 방법으로 다시 사용할 수도 있다. 컴퓨터 프로그래밍에서의 변수는 긴 이름이 자주 나오며, 어떻게 이용할 것인지에 대한 설명을 나타내는 반면 수학에서의 변수는 짧은 시간 동안 쓰이는 간결한, 한 두 개 문자 이름이다.
#
# 컴파일러는 변수의 상징적인 이름을 데이터의 실제 위치로 치환해야 한다. 변수 값, 형, 위치는 일반적으로 고정된 채 유지되는 반면 위치에 저장되어 있는 데이터는 프로그램 실행 도중 변경될 수 있다.
# <위키백과>
# - 전역변수
# - 지역변수

# %%
a = '3.14'
a = float(a)
a
# Out:
# 3.14

# %% [markdown]
# ## 변수 선언
# - 변수명  =  값
# - hello = ‘안녕 파이썬’
# - a = 123
# - p = 3.14

# %%
hello = '안녕파이썬'
print(hello)

p = 3.14
p = p + 0.0015
print(p, '반지름이 5인 원의 면적은', 5 * 5 * p)
# Out:
# 안녕파이썬
# 3.1415 반지름이 5인 원의 면적은 78.53750000000001

# %% [markdown]
#
# ## 변수에 값 할당하기(바인딩)
# -  = 기호의 의미 (할당연산자)
# -  = 기호는 ‘같다’는 의미가 아니라 ‘오른쪽의 것을 왼쪽으로 넣는다’는 의미
#      - a ← 100과 같은 개념
#
# ![image.png](data:image/png;base64,...)

# %%
a =  '10' # 바인딩
print(a)
# Out:
# 10

# %% [markdown]
# ## 변수명 작성 규칙
#     - 첫 글자는 반드시 영문 대소문자 혹은 언더바(_)로 시작합니다. (1name =’길동‘ (x))
#     - 나머지 글자들은 영문자, 숫자 혹은 언더바(_)로 이루어집니다. 단, 언더바를 제외한 특수 기호는 쓰지 못합니다.
#     - 대소문자를 구분합니다. 그렇기 때문에 ‘name’과 ‘nAme’은 다른 변수입니다.
#     - 길이에 대한 제약이 없지만 짧을수록 좋습니다.(커뮤니티에서 권하는 소스코드 한 줄의 문자 개수는 79개임)
#     - 다음 문자들은 이미 파이썬이 다른 용도로 사용하고 있기 때문에 변수명으로 사용할 수 없습니다. 이런 단어들을 보통 ‘예약어’라고 부릅니다.
#     - 예약어
# ![image02.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # 변수의 역할

# %% [markdown]
# ##  데이터를 활용할 때

# %%
print('hello Python')
print('hello Python')
print('hello Python')
print('hello Python')
print('hello Python')
# Out:
# hello Python
# hello Python
# hello Python
# hello Python
# hello Python

# %%
문자 = '안녕 Python'
print(문자)
print(문자)
print(문자)
print(문자)
print(문자)
# Out:
# 안녕 Python
# 안녕 Python
# 안녕 Python
# 안녕 Python
# 안녕 Python

# %% [markdown]
# ##  입력(input)함수
# - input() 함수로 입력받은 데이터를 변수에 할당

# %%
num = int(input('숫자 입력 :'))

print(num) 
# 변수에 할당된 값을 수정하면 처리가 달라질 수 있다
# input 함수 사용 시에는 변수에 담아야지만 다시 사용할 수 있다
# Out:
# 숫자 입력 :7
# 7

# %% [markdown]
# # 코딩해보기

# %% [markdown]
# ## 문제1
# 학교 식당에서 식권을 구입한다.<br> (1) 짜장면의 가격을 변수에 할당하고 (2) 짜장면을 **3개** 구입했을때 **총 가격**을 출력

# %%
# (1)
짜장면 = 3000
# (2)
print('짜장면 3개의 구입 총 가격 :', 짜장면 * 3)
# Out:
# 짜장면 3개의 구입 총 가격 : 9000

# %% [markdown]
# ## 문제2
# 학교 식당에서 식권을 구입할때 (1) 짜장면의 가격을 변수에 할당하고 (2) 짜장면을 **몇개를 구입하겠는가를 입력**받은 후 (3) 총 가격을 출력

# %%
# (1)
짜장면 = 3000
# (2)
수량 = int(input('짜장면을 몇 개 구입하시겠습니까?: '))
# (3)
print('주문하신 짜장면은 :', 수량, '그릇, 총 가격은 : ', 짜장면 * 수량)
# Out:
# 짜장면을 몇 개 구입하시겠습니까?: 4
# 주문하신 짜장면은 : 4 그릇, 총 가격은 :  12000

# %% [markdown]
# ## 문제3
# 에이컨이 월 48,584원에 무이자 36개월의 조건으로 홈쇼핑에서 판매되고 있습니다. <br>총 금액을 계산한 후 이를 화면에 출력해보세요. (변수사용하기)

# %%
에어컨 = 48584
기간 = 3
print('에어컨 구입 총 금액 : ', 에어컨 * 기간)
# Out:
# 에어컨 구입 총 금액 :  145752

# %% [markdown]
# ## 문제4
# 컴퓨터를 구입하려고 합니다.<br> 컴퓨터 가격과 할부 개월 수를 입력받은후, 월 지불금액을 계산하려는 프로그램을 작성합니다. (입력과 출력에 사용되는 형식을 적절히 정하기)

# %%
가격 = int(input('컴퓨터의 가격은? : '))
할부 = int(input('컴퓨터의 할부 개월 수는? : '))
지불 = 가격/할부
print('월 지불금액은', 지불, '원 입니다.')
# Out:
# 컴퓨터의 가격은? : 1200000
# 컴퓨터의 할부 개월 수는? : 12
# 월 지불금액은 100000.0 원 입니다.
