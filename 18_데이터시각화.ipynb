# %% [markdown]
# <a href="https://colab.research.google.com/github/mellmelt/2021_ss_winter/blob/main/18_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 코랩에서 한글 폰트 설정
# 1) 한글 폰트 코드 실행
#
# ```
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# ```
#
# 2) 런타임 - 런타임 다시시작
#
# 3) 글꼴 지정 명령어
#
# ```
# plt.rc('font', family='NanumGothic')
# ```

# %%
# 한글 폰트 설정
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
import matplotlib.pyplot as plt

# %%
mon = ['mar','apr','may','jun','jul']
sales = [1,5,7,3,7]

# 한글 폰트 설정
plt.rc('font', family='NanumGothic')
plt.title('월별 판매 실적')
plt.plot(mon, sales)
plt.show()

# %% [markdown]
# 런타임을 재실행했으므로 변수를 다시 만들어주고, 라이브러리를 다시 import 해야 함
#
#
# ```
# import matplotlib.pyplot as plt
#
# mon = ['mar','apr','may','jun','jul']
# sales = [1,5,7,3,7]
#
# # 한글 폰트 설정
#
# plt.title('월별 판매 실적')
# plt.plot(mon, sales)
# plt.show()
# ```

# %% [markdown]
# - 모듈
#     - 특정 기능이 정의되어 있는 단일 파일
# - 패키지
#     - 여러 모듈을 모아둔것
# - 라이브러리
#     - 모듈과 패키지를 모아 둔 곳
#         - 표준라이브러리 - 파이썬에서 공식적으로 제공
#         - 외부라이브러리 - 필요시 별도록 설치해 주어야 한다.
#     -

# %%
import random
help (random)

# %%
import matplotlib
help(matplotlib)

# %% [markdown]
# # 1. [matplotlib 라이브러리](https://matplotlib.org/stable/gallery/index.html)
#
#
# > 라이브러리는 다양한 명령어를 포함하고 있다. </br>
#
# ex. operator 라이브러리 : 각종 연산자 명령어들 집합</br>
# ex. random 라이브러리 : 임의의 수를 뽑는 명령어들 집합</br>
#
# </br>
# </br>
#
#
# <img src='https://github.com/teacher-jiejie/allinone_AI/blob/images/80_%E1%84%85%E1%85%A1%E1%84%8B%E1%85%B5%E1%84%87%E1%85%B3%E1%84%85%E1%85%A5%E1%84%85%E1%85%B5.png?raw=true' width = 500>
#
# </br>
# </br>
# </br>
#
# > import 라이브러리명 as 닉네임</br>
#
# 닉네임.명령어A()</br>
# 닉네임.명령어B()</br>

# %% [markdown]
# 매출그래프 그리기
#
# ```
# 3-7월 매출
#
# 3월 = 1
# 4월 = 5
# 5월 = 7
# 6월 = 3
# 7월 = 7
# ```

# %% [markdown]
# ### 선 그래프 그리기

# %%
#맷플로립 패키지 호출
import matplotlib.pyplot as plt
#값으로 선그래프그리기 [1,5,7,3,7]
plt.plot([1,5,7,3,7])

# %%
#값으로 선그래프그리기 [1,5,7,3,7]
plt.plot([1,5,7,3,7])
plt.show()

# %%
#sales 선그래프그리기
sales = [1,5,7,3,7]
plt.plot(sales)
plt.show()

# %% [markdown]
# ### x축 추가하기
#
#
# ```
# plt.plot(x축, y축)
# plt.show()
# ```

# %%
# x축 추가
mon = ['mar','apr','may','jun','jul']
sales = [1, 5, 7, 3, 7]

# X축, y축
plt.plot(mon,sales)
plt.show()

# %% [markdown]
# # 2. 그래프 꾸미기

# %% [markdown]
# ### 그래프 제목 추가하기
#
#
# ```
# plt.title('제목')
# plt.plot(x축, y축)
# plt.show()
# ```

# %%
# 'monthly sales' 챠트제목 삽입
plt.title('monthly sales')
plt.plot(mon, sales)
plt.show()

# %%
# 한글 '월별 판매 실적' 챠트제목 삽입
plt.title('월별 판매 실적')
plt.plot(mon, sales)
plt.show()

# %% [markdown]
# # 챠트에 한글폰트 설정

# %%
mon = ['mar','apr','may','jun','jul']
sales = [1,5,7,3,7]

plt.rc('font', family='NanumGothic')
plt.title('월별 판매 실적')
plt.plot(mon, sales)
plt.show()

# %% [markdown]
# ### 그래프 색상 변경
#
#
# ```
# # 그래프 그리는 명령어에 color 옵션 추가
# plt.plot(x축, y축, color = 'r')
# ```

# %%
plt.rc('font', family='NanumGothic')
plt.title('월별 판매 실적')
# 그래프 색상 변경
plt.plot(mon, sales,color = 'r')
plt.show()

# %% [markdown]
# <img src = 'https://github.com/teacher-jiejie/allinone_AI/blob/images/22_%EA%B7%B8%EB%9E%98%ED%94%84%20%EC%BB%AC%EB%9F%AC.png?raw=true' width = 500>

# %% [markdown]
# ### 해상도 설정 : 그래프를 선명하게
#
# ```
# plt.figure(dpi=해상도)
# plt.title('제목')
# plt.plot(x축, y축, color = '')
# plt.show()
# ```

# %%
# 해상도 설정  
plt.figure(dpi=100)
plt.rc('font', family='NanumGothic')
plt.title('월별 판매 실적')
plt.plot(mon, sales, color ='b')
plt.show()

# %% [markdown]
# ### 범례 나타내기
#
#
# ```
# plt.plot(x축, y축, label = '범례 내용')
# plt.legend()      # 범례를 화면에 나타내기
# plt.show()
# ```

# %%
plt.figure(dpi=100)
plt.title('월별 판매 실적')
# 범례 label
plt.plot(mon, sales, color = 'b', label = '단위:개수')
# 범례를 화면에 나타내는 legend()
plt.legend(loc= 'lower center' )
plt.show()

# %%
plt.legend?

# %% [markdown]
# ## 그래프 그리는 포맷
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.title('그래프 제목')
# plt.plot(x축 데이터, y축 데이터)
# plt.show()
# ```
#
# 그래프 명령어 plt.plot()에 사용가능한 옵션
#
# ```
# color = '색상이름'
# label = '범례내용'
# ```
#
# 기타 사용가능한 명령어
# ```
# plt.figure(dpi=150)     # 그래프 해상도 설정
# plt.legend()            # 범례 나타내기
# ```

# %% [markdown]
# # 3. 다양한 그래프
# ### plt.bar() : 막대그래프 - 세로형

# %%
plt.rc('font', family='NanumGothic')
plt.title('월별 판매 실적')
plt.bar(mon,sales)
plt.show()

# %%
plt.bar(sales)
plt.show()
# 선그래프는 sales 로만 그래프 그리기 가능이었는데 막대는 x, y축 값 모두 있어야 함
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-f237e1fe1713> in <module>()
# ----> 1 plt.bar(sales)
#       2 plt.show()
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %% [markdown]
# plt.bar()는 x축 리스트, y축 리스트 두 개 모두 넣어야 한다.

# %% [markdown]
# ### range() 사용하기

# %%
plt.rc('font', family='NanumGothic')
plt.title('월별 판매 실적')
plt.bar(range(3,8)   , sales) # [3, 4, 5, 6, 7]
plt.show()

# %% [markdown]
# ### range(시작숫자, 종료숫자, 간격)
#
# 시작숫자부터 종료숫자까지 간격을 두어 숫자를 선택함 <br/>
#
#
# ```
# range(2, 11, 2)
# ```
# 2부터 11까지 간격 2를 두고 숫자 선택
# -> 2, 4, 6, 8, 10

# %%
plt.rc('font', family='NanumGothic')
plt.title('월별 판매 실적')
plt.bar(range(2,12,2), sales, color = 'b') # [2, 4, 6, 8, 10]
plt.show()

# %% [markdown]
# ### plt.barh() : 막대그래프 - 가로형

# %%
plt.rc('font', family='NanumGothic')
plt.title('월별 판매 실적')
#y축의 값 3,4,5,6 으로 정하기
plt.barh(range(3,8),sales, color='pink')
plt.show()

# %% [markdown]
# ### plt.hist() : 히스토그램

# %%
sales=[4,6,1,2,7,9,4,5,4,2,6,9]

# %%
plt.rc('font', family='NanumGothic')
plt.title('판매 실적 히스토그램')
plt.hist(sales)
plt.show()

# %% [markdown]
# ### plt.pie() : 원그래프
#
#
# ```
# 우리학교 100명의 혈액형을 조사한 결과가 다음과 같다.
#
# A형 = 28명
# B형 = 20명
# O형 = 40명
# AB형 = 12명
# ```

# %%
b_type=[28,20,40,12]
plt.pie(b_type)
plt.show()

# %% [markdown]
# #### 원그래프 각 항목에 라벨 붙이기
#
#
# ```
# plt.pie(리스트, labels = 라벨리스트)
# ```

# %%
b_type=[28,20,40,12]
b_name = ['A형', 'B형', 'O형', 'AB형']
plt.rc('font', family='NanumGothic')
plt.title('혈액형 비율')
plt.pie(b_type, labels= b_name)
plt.show()

# %% [markdown]
# #### 원그래프 항목에 퍼센트 표시
#
# ```
# plt.pie(리스트, labels = 라벨리스트, autopct = '%1.1f%%')
# ```

# %%
b_type = [25, 19, 37, 11]
b_name = ['A형', 'B형', 'O형', 'AB형']

plt.rc('font', family='NanumGothic')
plt.title('혈액형 비율')
plt.pie(b_type, labels= b_name, autopct = '%1.1f%%')
plt.show()

# %% [markdown]
# ### plt.scatter() : 산점도
#
# > 국어를 잘하는 친구가 영어도 잘할까?
#
#
# ```
# 국어점수와 영어점수의 상관관계 알아보기
#
# kor =[80, 20, 50, 20, 10, 50, 60, 30, 60]
# eng =[90, 40, 60, 40, 10, 30, 50, 70, 90]
# ```

# %%
kor =[80, 20, 50, 20, 10, 50, 60, 30, 60]
eng =[90, 40, 60, 40, 10, 30, 50, 70, 90]

plt.scatter(kor, eng)
plt.show()

# %% [markdown]
# <img src = 'https://github.com/teacher-jiejie/allinone_AI/blob/images/81_scatter.png?raw=true' width=800>

# %% [markdown]
# ### 그래프 꾸미기 : x축 이름, y축 이름 붙이기
#
#
# ```
# plt.xlabel('x축 이름')
# plt.ylabel('y축 이름')
# ```

# %%
plt.figure(dpi=100)
plt.rc('font', family='NanumGothic')
plt.title('국어점수와 영어점수와의 상관관계')
plt.scatter(kor, eng, c='indigo')
plt.xlabel('국어점수')
plt.ylabel('영어점수')
plt.show()

# %% [markdown]
# # 그래프 명령어 정리
# **그래프 그리는 포맷**
# ```
# import matplotlib.pyplot as plt
#
# plt.title('그래프 제목')
# # --- 그래프 형태에 따라 알맞은 명령어 넣기 ---
# plt.show()
# ```
#
#
# **그래프 유형별 명령어**
# ```
# # ---- 그래프 유형별 명령어
# # 꺾은선그래프
# plt.plot([x축 리스트], [y축 리스트])
#
# # 막대그래프 세로
# plt.bar([x축 리스트], [y축 리스트])
#
# # 막대그래프 가로
# plt.barh([x축 리스트], [y축 리스트])
#
# # 히스토그램 (x축, y축을 구분하지 않고 하나의 리스트만 넣음)
# plt.hist( [리스트], bins = 구간개수 )
#
# # 원 그래프 (x축, y축을 구분하지 않고 하나의 리스트만 넣음)
# plt.pie( [리스트], labels = [데이터 구간 이름])
#
# # 산점도
# plt.scatter([x축 리스트], [y축 리스트])
# ```
#
# **그래프 명령어 내에 추가 가능한 옵션**
#
# ```
# color = '색상이름'
# alpha = 투명도
#
# # plt.plot(), plt.bar(), plt.barh(), plt.scatter()는 label 사용
# label = '범례내용'
#
# # plt.pie(), plt.boxplot()은 labels 사용
# labels = [범례 리스트]
#
# # plt.pie()에 퍼센트 자동 표시
# autopct = ‘%1.1%%’
# ```
#
# **기타 사용가능한 명령어**
#
#
# ```
# plt.legend()            # 범례 나타내기
# plt.xlabel()            # x축 이름 붙이기
# plt.ylabel()            # y축 이름 붙이기
# ```
